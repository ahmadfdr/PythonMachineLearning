# %%
import pandas as pd
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 10,6

# %%
df = pd.read_excel('TKTK1.xlsx', sheet_name='KOPI SUSU')
df
# Out:
#       Tanggal  Penjualan Kopi Susu
# 0  2021-05-01               390000
# 1  2021-05-02               330000
# 2  2021-05-03               285000
# 3  2021-05-04               210000
# 4  2021-05-05               195000
# ..        ...                  ...
# 88 2021-07-28               180000
# 89 2021-07-29               195000
# 90 2021-07-30               210000
# 91 2021-07-31               270000
# 92 2021-07-31               285000
#
# [93 rows x 2 columns]

# %%
df.shape
# Out:
# (93, 2)

# %%
df1 = df.reset_index()['Penjualan Kopi Susu']
df1
# Out:
# 0     390000
# 1     330000
# 2     285000
# 3     210000
# 4     195000
#        ...
# 88    180000
# 89    195000
# 90    210000
# 91    270000
# 92    285000
# Name: Penjualan Kopi Susu, Length: 93, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
#LSTM is sensitive to the scale of the data, so we apply MinMax Scaler
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range = (0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))
print(df1)
# Out:
# [[0.84615385]
#  [0.69230769]
#  [0.57692308]
#  [0.38461538]
#  [0.34615385]
#  [0.26923077]
#  [0.30769231]
#  [0.34615385]
#  [0.42307692]
#  [0.23076923]
#  [0.07692308]
#  [0.03846154]
#  [0.03846154]
#  [0.23076923]
#  [0.46153846]
#  [0.46153846]
#  [0.26923077]
#  [0.19230769]
#  [0.15384615]
#  [0.        ]
#  [0.23076923]
#  [0.61538462]
#  [0.46153846]
#  [0.26923077]
#  [0.30769231]
#  [0.19230769]
#  [0.23076923]
#  [0.42307692]
#  [0.69230769]
#  [0.65384615]
#  [0.11538462]
#  [0.07692308]
#  [0.19230769]
#  [0.30769231]
#  [0.42307692]
#  [0.46153846]
#  [0.42307692]
#  [0.07692308]
#  [0.03846154]
#  [0.15384615]
#  [0.23076923]
#  [0.69230769]
#  [0.88461538]
#  [1.        ]
#  [0.65384615]
#  [0.61538462]
#  [0.46153846]
#  [0.34615385]
#  [0.5       ]
#  [0.61538462]
#  [0.53846154]
#  [0.42307692]
#  [0.38461538]
#  [0.34615385]
#  [0.26923077]
#  [0.30769231]
#  [0.38461538]
#  [0.46153846]
#  [0.42307692]
#  [0.34615385]
#  [0.30769231]
#  [0.30769231]
#  [0.46153846]
#  [0.46153846]
#  [0.42307692]
#  [0.23076923]
#  [0.30769231]
#  [0.23076923]
#  [0.34615385]
#  [0.38461538]
#  [0.46153846]
#  [0.42307692]
#  [0.38461538]
#  [0.34615385]
#  [0.26923077]
#  [0.23076923]
#  [0.34615385]
#  [0.46153846]
#  [0.53846154]
#  [0.46153846]
#  [0.26923077]
#  [0.26923077]
#  [0.19230769]
#  [0.23076923]
#  [0.30769231]
#  [0.42307692]
#  [0.38461538]
#  [0.34615385]
#  [0.30769231]
#  [0.34615385]
#  [0.38461538]
#  [0.53846154]
#  [0.57692308]]

# %%
#Splitting the data into train and test split
training_size = int(len(df1)*0.70)
test_size = len(df)-training_size
train_data, test_data = df1[0:training_size,:], df1[training_size:len(df1),:1]
training_size, test_size
# Out:
# (65, 28)

# %%
train_data
# Out:
# array([[0.84615385],
#        [0.69230769],
#        [0.57692308],
#        [0.38461538],
#        [0.34615385],
#        [0.26923077],
#        [0.30769231],
#        [0.34615385],
#        [0.42307692],
#        [0.23076923],
#        [0.07692308],
#        [0.03846154],
#        [0.03846154],
#        [0.23076923],
#        [0.46153846],
#        [0.46153846],
#        [0.26923077],
#        [0.19230769],
#        [0.15384615],
#        [0.        ],
#        [0.23076923],
#        [0.61538462],
#        [0.46153846],
#        [0.26923077],
#        [0.30769231],
#        [0.19230769],
#        [0.23076923],
#        [0.42307692],
#        [0.69230769],
#        [0.65384615],
#        [0.11538462],
#        [0.07692308],
#        [0.19230769],
#        [0.30769231],
#        [0.42307692],
#        [0.46153846],
#        [0.42307692],
#        [0.07692308],
#        [0.03846154],
#        [0.15384615],
#        [0.23076923],
#        [0.69230769],
#        [0.88461538],
#        [1.        ],
#        [0.65384615],
#        [0.61538462],
#        [0.46153846],
#        [0.34615385],
#        [0.5       ],
#        [0.61538462],
#        [0.53846154],
#        [0.42307692],
#        [0.38461538],
#        [0.34615385],
#        [0.26923077],
#        [0.30769231],
#        [0.38461538],
#        [0.46153846],
#        [0.42307692],
#        [0.34615385],
#        [0.30769231],
#        [0.30769231],
#        [0.46153846],
#        [0.46153846],
#        [0.42307692]])

# %%
import numpy
#Convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range (len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   #i=0, 0,1,2,3----9   10
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#Reshape into X=t, t+1, t+2, t+3, and Y=t+4
time_step = 10
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (54, 10)
# (54,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (17, 10)
# (17,)
# (None, None)

# %%
#Reshape input to be [samples, time_steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
#Create the stacked LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(10,1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 10, 50)            10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10, 50)            20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, validation_data=(X_test, ytest), epochs=50, batch_size=1, verbose=1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0457 - val_loss: 0.0131
# Epoch 2/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0495 - val_loss: 0.0124
# Epoch 3/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0473 - val_loss: 0.0107
# Epoch 4/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0457 - val_loss: 0.0108
# Epoch 5/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0465 - val_loss: 0.0120
# Epoch 6/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0464 - val_loss: 0.0108
# Epoch 7/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0461 - val_loss: 0.0112
# Epoch 8/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0467 - val_loss: 0.0168
# Epoch 9/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0452 - val_loss: 0.0109
# Epoch 10/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0463 - val_loss: 0.0130
# Epoch 11/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0455 - val_loss: 0.0127
# Epoch 12/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0467 - val_loss: 0.0125
# Epoch 13/50
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0458 - val_loss: 0.0109
# Epoch 14/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0484 - val_loss: 0.0107
# Epoch 15/50
# 54/54 [==============================] - 1s 13ms/step - loss: 0.0444 - val_loss: 0.0129
# Epoch 16/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0450 - val_loss: 0.0105
# Epoch 17/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0435 - val_loss: 0.0105
# Epoch 18/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0431 - val_loss: 0.0105
# Epoch 19/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0421 - val_loss: 0.0098
# Epoch 20/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0371 - val_loss: 0.0076
# Epoch 21/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0386 - val_loss: 0.0070
# Epoch 22/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0296 - val_loss: 0.0075
# Epoch 23/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0261 - val_loss: 0.0070
# Epoch 24/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0233 - val_loss: 0.0062
# Epoch 25/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0233 - val_loss: 0.0041
# Epoch 26/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0210 - val_loss: 0.0075
# Epoch 27/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0187 - val_loss: 0.0041
# Epoch 28/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0193 - val_loss: 0.0043
# Epoch 29/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0190 - val_loss: 0.0039
# Epoch 30/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0194 - val_loss: 0.0040
# Epoch 31/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0168 - val_loss: 0.0056
# Epoch 32/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0180 - val_loss: 0.0040
# Epoch 33/50
# 54/54 [==============================] - 1s 15ms/step - loss: 0.0165 - val_loss: 0.0045
# Epoch 34/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0166 - val_loss: 0.0039
# Epoch 35/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0163 - val_loss: 0.0045
# Epoch 36/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0164 - val_loss: 0.0037
# Epoch 37/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0160 - val_loss: 0.0041
# Epoch 38/50
# 54/54 [==============================] - 1s 14ms/step - loss: 0.0168 - val_loss: 0.0040
# Epoch 39/50
# 54/54 [==============================] - 1s 10ms/step - loss: 0.0151 - val_loss: 0.0049
# Epoch 40/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0164 - val_loss: 0.0045
# Epoch 41/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0170 - val_loss: 0.0051
# Epoch 42/50
# 54/54 [==============================] - 1s 11ms/step - loss: 0.0168 - val_loss: 0.0053
# Epoch 43/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0150 - val_loss: 0.0058
# Epoch 44/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0148 - val_loss: 0.0041
# Epoch 45/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0164 - val_loss: 0.0040
# Epoch 46/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0149 - val_loss: 0.0048
# Epoch 47/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0159 - val_loss: 0.0073
# Epoch 48/50
# 54/54 [==============================] - 1s 17ms/step - loss: 0.0149 - val_loss: 0.0054
# Epoch 49/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0141 - val_loss: 0.0050
# Epoch 50/50
# 54/54 [==============================] - 1s 16ms/step - loss: 0.0130 - val_loss: 0.0048

# %%
import tensorflow as tf

# %%
#Do the prediction and check performance metrics
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
#Transformback to original form
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
#Calculate RSME perfomance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train, train_predict))
# Out:
# 0.11536211967891907

# %%
#Test data RSME
math.sqrt(mean_squared_error(ytest, test_predict))
# Out:
# 0.06897899133863625

# %%
###Plotting
#Shift train prediction for plotting
look_back = 10
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict)+look_back, :] = train_predict
#Shift test prediction for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
#Plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot, label='Train Data')
plt.plot(testPredictPlot, label='Test Data')
plt.legend(loc='best')
plt.show()

# %%
len(test_data)
# Out:
# 28

# %%
x_input = test_data[18:].reshape(1,-1)
x_input.shape
# Out:
# (1, 10)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
temp_input
# Out:
# [0.23076923076923075,
#  0.3076923076923077,
#  0.423076923076923,
#  0.3846153846153846,
#  0.34615384615384615,
#  0.3076923076923077,
#  0.34615384615384615,
#  0.3846153846153846,
#  0.5384615384615384,
#  0.5769230769230769]

# %%
#Demonstrate prediction next 10 days
from numpy import array
lst_output = []
n_steps = 10
i = 0
while(i<10):
    if (len(temp_input)>10):
        #print temp_input
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input=x_input.reshape((1, n_steps, 1))
        #print x_input
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print temp_input
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1

print(lst_output)
# Out:
# [0.38869148]
# 11
# 1 day input [0.30769231 0.42307692 0.38461538 0.34615385 0.30769231 0.34615385
#  0.38461538 0.53846154 0.57692308 0.38869148]
# 1 day output [[0.39143828]]
# 2 day input [0.42307692 0.38461538 0.34615385 0.30769231 0.34615385 0.38461538
#  0.53846154 0.57692308 0.38869148 0.39143828]
# 2 day output [[0.39278558]]
# 3 day input [0.38461538 0.34615385 0.30769231 0.34615385 0.38461538 0.53846154
#  0.57692308 0.38869148 0.39143828 0.39278558]
# 3 day output [[0.39349672]]
# 4 day input [0.34615385 0.30769231 0.34615385 0.38461538 0.53846154 0.57692308
#  0.38869148 0.39143828 0.39278558 0.39349672]
# 4 day output [[0.39304778]]
# 5 day input [0.30769231 0.34615385 0.38461538 0.53846154 0.57692308 0.38869148
#  0.39143828 0.39278558 0.39349672 0.39304778]
# 5 day output [[0.39166993]]
# 6 day input [0.34615385 0.38461538 0.53846154 0.57692308 0.38869148 0.39143828
#  0.39278558 0.39349672 0.39304778 0.39166993]
# 6 day output [[0.38957474]]
# 7 day input [0.38461538 0.53846154 0.57692308 0.38869148 0.39143828 0.39278558
#  0.39349672 0.39304778 0.39166993 0.38957474]
# 7 day output [[0.38752577]]
# 8 day input [0.53846154 0.57692308 0.38869148 0.39143828 0.39278558 0.39349672
#  0.39304778 0.39166993 0.38957474 0.38752577]
# 8 day output [[0.38581714]]
# 9 day input [0.57692308 0.38869148 0.39143828 0.39278558 0.39349672 0.39304778
#  0.39166993 0.38957474 0.38752577 0.38581714]
# 9 day output [[0.38555184]]
# [[0.3886914849281311], [0.3914382755756378], [0.39278557896614075], [0.39349672198295593], [0.3930477797985077], [0.3916699290275574], [0.38957473635673523], [0.3875257670879364], [0.38581714034080505], [0.3855518400669098]]

# %%
day_new = np.arange(1,11)
day_pred = np.arange(11,21)

# %%
import matplotlib.pyplot as plt

# %%
len(df1)
# Out:
# 93

# %%
# df3=df1.tolist()
# df3.extend(lst_output)

# %%
plt.plot(day_new, scaler.inverse_transform(df1[83:]))
plt.plot(day_pred, scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[30:])
